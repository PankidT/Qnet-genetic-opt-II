# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('Results/result_test_2023-09-27 15:24:56.pickle', "rb") as f:
    results = pickle.load(f)
# Out:
# 1

# %%
results.plot()
# Out:
# /Users/poramat/Documents/qwanta-ii/src/all_function.py:208: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r.-" (-> color='r'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, self.exper_config.CostHistory.Mean, 'r.-', label='mean cost', color=color)
# /Users/poramat/Documents/qwanta-ii/src/all_function.py:215: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b+" (-> color='b'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, self.exper_config.CostHistory.Min , 'b+',label='min cost', color=color)

# %%
results.exper_config
# Out:
# ExperimentConfig(ExperimentName='This is template config', DateCreated='2023-09-29 12:55:24', QuantumNetworkSimulationConfig=ExperimentConfig.QuantumNetworkSimulationConfig(NetworkGeneration='0G', NumHops=2), GeneticAlgorithmConfig=ExperimentConfig.GeneticAlgorithmConfig(PopulationSize=10, DnaStartPosition=0.5, Elitism=0.2, MutationRate=0.8, MutationSigma=0.3, ObjectiveFidelity=0.7, Weight=0.5), ParameterHistory=ExperimentConfig.ParameterHistory(Loss=[], GateError=[], MeasurementError=[], MemoryTime=[]), FidelityHistory=ExperimentConfig.FidelityHistory(Max=[0.7068333333333332, 0.7193333333333334, 0.936], Mean=[0.4035833333333333, 0.5376, 0.6845333333333334], Min=[0.2515, 0.29433333333333334, 0.2743333333333334]), CostHistory=ExperimentConfig.CostHistory(Max=[10.163531556993558, 13.668134031411947, 12.417766741222973], Mean=[5.11067103757848, 4.220376558001567, 4.169709553005795], Min=[2.633602415911069, 2.133602415911069, 2.133602415911069]))
