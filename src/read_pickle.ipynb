# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('Results/result_First experiment_2023-09-29 12:55:24.pickle', "rb") as f:
    results = pickle.load(f)
# Out:
# 1

# %%
results.plot()
# Out:
# /Users/poramat/Documents/qwanta-ii/src/all_function.py:214: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r.-" (-> color='r'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, self.exper_config.CostHistory.Mean, 'r.-', label='mean cost', color=color)
# /Users/poramat/Documents/qwanta-ii/src/all_function.py:221: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b+" (-> color='b'). The keyword argument will take precedence.
#   ax[1, 1].plot(x, self.exper_config.CostHistory.Min , 'b+',label='min cost', color=color)
# Experiment Name: First experiment

# %%
print(results.exper_config.CostHistory.Max)
print(results.exper_config.CostHistory.Mean)
print(results.exper_config.CostHistory.Min)
# Out:
# [33.72846919293553, 11.466834939881663, 116.40520375752057]
# [14.643630326056805, 9.116234401762034, 24.3898800875757]
# [6.148023573906992, 6.148023573906992, 6.148023573906992]
